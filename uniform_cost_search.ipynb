# %%
import heapq

# uniform cost function
# returns the minimum cost and the path with minimum cost
def  uniform_cost_search(start, goal, graph, cost):
    found_nodes = [None] * len(graph)
    found_nodes[start] = (0, [])
    print(found_nodes)
    available_nodes = [start]

    while not all(found_nodes[index] for index in goal):
        current_node_index = heapq.heappop(available_nodes)
        print(current_node_index)
        for adjacent_node in graph[current_node_index]:
            if found_nodes[adjacent_node] is None:
                print(current_node_index)
                path = found_nodes[current_node_index][1].copy()
                path.append(adjacent_node)
                print(path)
                found_nodes[adjacent_node] = (found_nodes[current_node_index][0] + cost[(current_node_index, adjacent_node)], path)
                heapq.heappush(available_nodes, adjacent_node)
            print(found_nodes)

    answer = {node: {'cost': found_nodes[node][0], 'path': found_nodes[node][1]} for node in goal}
#     **************************************
#     ******** Write your code here ********
#     **************************************

    return answer
 
# main function
if __name__ == '__main__':
     
    # create a graph with no more than 30 nodes
    graph, cost = [[] for i in range(30)], {}
 
    # add edges to the graph
    graph[0].append(4)
    graph[0].append(5)
    graph[0].append(16)
    graph[2].append(1)
    graph[3].append(1)
    graph[4].append(2)
    graph[4].append(3)
    graph[4].append(5)
    graph[5].append(8)
    graph[5].append(18)
    graph[6].append(3)
    graph[6].append(7)
    graph[8].append(16)
    graph[8].append(17)
    graph[16].append(17)
    graph[18].append(6)
    
 
    # add cost to each edge
    cost[(0, 4)] = 3
    cost[(0, 5)] = 9
    cost[(0, 16)] = 1
    cost[(2, 1)] = 2
    cost[(3, 1)] = 2
    cost[(4, 2)] = 1
    cost[(4, 3)] = 8
    cost[(4, 5)] = 2
    cost[(5, 8)] = 3
    cost[(5, 18)] = 2
    cost[(6, 3)] = 3
    cost[(6, 7)] = 2
    cost[(8, 16)] = 4
    cost[(8, 17)] = 4
    cost[(16, 17)] = 15
    cost[(18, 6)] = 1
    
    # set start state 
    start = 0
    
    # set goal state, there can be multiple goal states
    goal = [7]
    
    # call uniform_search_cost function to get the minimum cost to reach the goal and the path with minumum cost
    # ****** You have to implement this function *****
    min_cost_info = uniform_cost_search(start, goal, graph, cost)

    for node, info in min_cost_info.items():
        print(f'Minimum cost from {start} to {node} is {info["cost"]}')
        print(f'Path: {info["path"]}')
# Out:
# [(0, []), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 0
# 0
# None
# [(0, []), None, None, None, (3, None), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 0
# None
# [(0, []), None, None, None, (3, None), (9, None), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 0
# None
# [(0, []), None, None, None, (3, None), (9, None), None, None, None, None, None, None, None, None, None, None, (1, None), None, None, None, None, None, None, None, None, None, None, None, None, None]
# 4
# 4
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 81
#      77 goal = [7]
#      79 # call uniform_search_cost function to get the minimum cost to reach the goal and the path with minumum cost
#      80 # ****** You have to implement this function *****
# ---> 81 min_cost_info = uniform_cost_search(start, goal, graph, cost)
#      83 for node, info in min_cost_info.items():
#      84     print(f'Minimum cost from {start} to {node} is {info["cost"]}')
#
# Cell In[10], line 17, in uniform_cost_search(start, goal, graph, cost)
#      15 if found_nodes[adjacent_node] is None:
#      16     print(current_node_index)
# ---> 17     path = found_nodes[current_node_index][1].copy().append(adjacent_node)
#      18     print(path)
#      19     found_nodes[adjacent_node] = (found_nodes[current_node_index][0] + cost[(current_node_index, adjacent_node)], path)
#
# AttributeError: 'NoneType' object has no attribute 'copy'
